# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df=pd.read_csv("C:\\Users\\geeth\\Downloads\\archive (1)\\healthcare_dataset.csv",encoding='unicode_escape')

# %%
df
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 0          Tiffany Ramirez   81  Female         O-          Diabetes
# 1              Ruben Burns   35    Male         O+            Asthma
# 2                Chad Byrd   61    Male         B-           Obesity
# 3        Antonio Frederick   49    Male         B-            Asthma
# 4      Mrs. Brandy Flowers   51    Male         O-         Arthritis
# ...                    ...  ...     ...        ...               ...
# 9995            James Hood   83    Male         A+           Obesity
# 9996       Stephanie Evans   47  Female        AB+         Arthritis
# 9997  Christopher Martinez   54    Male         B-         Arthritis
# 9998           Amanda Duke   84    Male         A+         Arthritis
# 9999             Eric King   20    Male         B-         Arthritis
#
#      Date of Admission             Doctor                   Hospital  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                10000 non-null  object
#  1   Age                 10000 non-null  int64
#  2   Gender              10000 non-null  object
#  3   Blood Type          10000 non-null  object
#  4   Medical Condition   10000 non-null  object
#  5   Date of Admission   10000 non-null  object
#  6   Doctor              10000 non-null  object
#  7   Hospital            10000 non-null  object
#  8   Insurance Provider  10000 non-null  object
#  9   Billing Amount      10000 non-null  float64
#  10  Room Number         10000 non-null  int64
#  11  Admission Type      10000 non-null  object
#  12  Discharge Date      10000 non-null  object
#  13  Medication          10000 non-null  object
#  14  Test Results        10000 non-null  object
# ...

# %%
df.describe()
# Out:
#                 Age  Billing Amount   Room Number
# count  10000.000000    10000.000000  10000.000000
# mean      51.452200    25516.806778    300.082000
# std       19.588974    14067.292709    115.806027
# min       18.000000     1000.180837    101.000000
# 25%       35.000000    13506.523967    199.000000
# 50%       52.000000    25258.112566    299.000000
# 75%       68.000000    37733.913727    400.000000
# max       85.000000    49995.902283    500.000000

# %%
df.shape
# Out:
# (10000, 15)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='object')

# %%
# Gender Based Analysis

# %%
ax=sns.countplot(x='Gender',data=df)
plt.title('Gender Analysis')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
#  Total Amount Analysis based on Gender

# %%
Health_gen=df.groupby(['Gender'],as_index=False)['Billing Amount'].sum()
sns.barplot(x='Gender',y='Billing Amount',data=Health_gen)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Billing Amount'>

# %%
#  creating column of age category

# %%
bins = [0, 18, 30, 40, 50, 60, 100] 
labels = ['0-18', '19-30', '31-40', '41-50', '51-60', '61+']
df['age_category'] = pd.cut(df['Age'], bins=bins, labels=labels, right=False)

# %%
print(df)
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 0          Tiffany Ramirez   81  Female         O-          Diabetes
# 1              Ruben Burns   35    Male         O+            Asthma
# 2                Chad Byrd   61    Male         B-           Obesity
# 3        Antonio Frederick   49    Male         B-            Asthma
# 4      Mrs. Brandy Flowers   51    Male         O-         Arthritis
# ...                    ...  ...     ...        ...               ...
# 9995            James Hood   83    Male         A+           Obesity
# 9996       Stephanie Evans   47  Female        AB+         Arthritis
# 9997  Christopher Martinez   54    Male         B-         Arthritis
# 9998           Amanda Duke   84    Male         A+         Arthritis
# 9999             Eric King   20    Male         B-         Arthritis
#
#      Date of Admission             Doctor                   Hospital  \
# ...

# %%
# Total Patients Age Category based on Gender

# %%
ax=sns.countplot(data=df,x='age_category',hue='Gender')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
# Total no Patients

# %%
total_patients = df['Name'].nunique()
print(f'The total number of patients in the DataFrame is: {total_patients}')
# Out:
# The total number of patients in the DataFrame is: 9378

# %%
# Total Counts of each Gender

# %%
Gender_counts = df['Gender'].value_counts()

print(Gender_counts)
# Out:
# Female    5075
# Male      4925
# Name: Gender, dtype: int64

# %%
# Total Blood Type Patients counts

# %%
blood_type_counts = df['Blood Type'].value_counts()

print(blood_type_counts)
# Out:
# AB-    1275
# AB+    1258
# B-     1252
# O+     1248
# O-     1244
# B+     1244
# A+     1241
# A-     1238
# Name: Blood Type, dtype: int64

# %%
#Total Medical cases affected based on blood type

# %%
    plt.figure(figsize=(12, 6))
    ax=sns.countplot(x="Blood Type",hue="Medical Condition",data=df,order=df['Blood Type'].value_counts().index)
    for bars in ax.containers:
        ax.bar_label(bars) 
    plt.title('Case Affected based on blood type')
# Out:
# Text(0.5, 1.0, 'Case Affected based on blood type')

# %%
#  Types of cases Admitted in hospital

# %%
Admission_type = df['Admission Type'].value_counts()
plt.pie(Admission_type, labels=Admission_type.index, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Types of cases Admitted')
plt.show()

# %%
#  Type of most medication used for patients

# %%
plt.figure(figsize=(12, 6))
ax=sns.countplot(x='Medication',hue='Medical Condition', data=df,dodge=True)
for bars in ax.containers:
    ax.bar_label(bars)    
plt.xlabel('Medicine used',)
plt.ylabel('Count')
plt.title('Most Medicine used for Patients')
plt.show()

# %%
#  Types of case results faced

# %%
Case_Results = df['Test Results'].value_counts()
plt.pie(Case_Results , labels=Case_Results .index, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Types of case results faced')
plt.show()

# %%
# Who is highest insurance provider for patients based on cases

# %%
plt.figure(figsize=(12, 6))
ax=sns.countplot(x='Insurance Provider',hue='Medical Condition', data=df,dodge=True)
for bars in ax.containers:
    ax.bar_label(bars)
plt.xlabel('Insurance Provider')
plt.ylabel('Count')
plt.title('Highest Insurance Provider for specific cases')
plt.show()

# %%
#Total Billing Amount got from specific medical cases

# %%
sum_of_Billig_Amount = df.groupby('Medical Condition')['Billing Amount'].sum()
sns.boxplot(x='Medical Condition', y='Billing Amount', data=df)
plt.xlabel('Cases')
plt.ylabel('Earned Amount')
plt.title('Total Earning from cases')
plt.show()

# %%
# Finding Length of stay of patients

# %%
df['Date of Admission'] = pd.to_datetime(df['Date of Admission'], format='%Y-%m-%d')
df['Discharge Date'] = pd.to_datetime(df['Discharge Date'], format='%Y-%m-%d')
df['Length of Stay'] = (df['Discharge Date'] - df['Date of Admission']).dt.days

# %%
print(df)
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 0          Tiffany Ramirez   81  Female         O-          Diabetes
# 1              Ruben Burns   35    Male         O+            Asthma
# 2                Chad Byrd   61    Male         B-           Obesity
# 3        Antonio Frederick   49    Male         B-            Asthma
# 4      Mrs. Brandy Flowers   51    Male         O-         Arthritis
# ...                    ...  ...     ...        ...               ...
# 9995            James Hood   83    Male         A+           Obesity
# 9996       Stephanie Evans   47  Female        AB+         Arthritis
# 9997  Christopher Martinez   54    Male         B-         Arthritis
# 9998           Amanda Duke   84    Male         A+         Arthritis
# 9999             Eric King   20    Male         B-         Arthritis
#
#      Date of Admission             Doctor                   Hospital  \
# ...

# %%
# Avg Length of stay:

# %%
average_length_of_stay = df['Length of Stay'].mean()

# %%
plt.hist(df['Length of Stay'], bins=10, color='green', edgecolor='black', alpha=0.7)
plt.axvline(average_length_of_stay, color='red', linestyle='dashed', linewidth=2, label='Avg Length of Stay')
plt.xlabel('Length of Stay (days)')
plt.ylabel('Frequency')
plt.title('Distribution of Length of Stay')
plt.legend()
plt.show()

# %%
# Length of stay based on admision type

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Admission Type', y='Length of Stay', data=df)
plt.title('Length of Stay by Admission Type')
plt.show()

# %%
# length of stay based on medical condition

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Medical Condition', y='Length of Stay', data=df)
plt.title('Length of Stay by Medical Condition')
plt.show()

# %%
# finding Billing Amount per day per patients

# %%
df['Billing Amount per Day'] = df['Billing Amount'] / df['Length of Stay']

# %%
print(df)
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 0          Tiffany Ramirez   81  Female         O-          Diabetes
# 1              Ruben Burns   35    Male         O+            Asthma
# 2                Chad Byrd   61    Male         B-           Obesity
# 3        Antonio Frederick   49    Male         B-            Asthma
# 4      Mrs. Brandy Flowers   51    Male         O-         Arthritis
# ...                    ...  ...     ...        ...               ...
# 9995            James Hood   83    Male         A+           Obesity
# 9996       Stephanie Evans   47  Female        AB+         Arthritis
# 9997  Christopher Martinez   54    Male         B-         Arthritis
# 9998           Amanda Duke   84    Male         A+         Arthritis
# 9999             Eric King   20    Male         B-         Arthritis
#
#      Date of Admission             Doctor                   Hospital  \
# ...

# %%
avg_billing_amount_of_day=df['Billing Amount per Day'].mean()
